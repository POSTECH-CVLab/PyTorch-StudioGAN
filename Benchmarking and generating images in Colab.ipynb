# %% [markdown]
# # Set-up

# %% [markdown]
# ## Install packages missing in Colab

# %%
import torch
print(torch.cuda.is_available())

assert torch.cuda.is_available(), "\nNeed access to the GPU, otherwise: \n\t 1. torchlars won't install \n\t 2. will take forever even to benchmark without training"
# Out:
# True

# %%
# !pip install torchlars
# !pip install ninja
# Out:
# Collecting torchlars
#   Downloading https://files.pythonhosted.org/packages/f5/12/633c1822dc87d72ad2a80ba40706c7a77056c68d6211351313ff0e96bda0/torchlars-0.1.2.tar.gz
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torchlars) (1.8.1+cu101)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torchlars) (3.7.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch->torchlars) (1.19.5)
# Building wheels for collected packages: torchlars
#   Building wheel for torchlars (setup.py) ... done
#   Created wheel for torchlars: filename=torchlars-0.1.2-cp37-cp37m-linux_x86_64.whl size=1953612 sha256=862e170d5284abf61afd4b617c6589eae2d9607b9be071929aa66fe3292833ea
#   Stored in directory: /root/.cache/pip/wheels/0e/a8/99/9647d66c1734f1f78ffb0e303273e1a301ecc8d0cb10473646
# Successfully built torchlars
# Installing collected packages: torchlars
# Successfully installed torchlars-0.1.2
# Collecting ninja
#   Downloading https://files.pythonhosted.org/packages/1d/de/393468f2a37fc2c1dc3a06afc37775e27fde2d16845424141d4da62c686d/ninja-1.10.0.post2-py3-none-manylinux1_x86_64.whl (107kB)
#      |████████████████████████████████| 112kB 18.3MB/s
# Installing collected packages: ninja
# Successfully installed ninja-1.10.0.post2

# %% [markdown]
# ## Mount Drive and `cd` to the folder

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
# %ls drive/MyDrive/colab_projects/PyTorch-StudioGAN
# Out:
# 'Benchmarking and generating images in Colab.ipynb'   LICENSE
#  checkpoints/                                         LICENSE-NVIDIA
#  data/                                                logs/
#  docs/                                               'logs (1)'/
#  environment.yml                                      README.md
#  figures/                                             src/
# 'Getting the data into Colab.ipynb'

# %%
# %cd drive/MyDrive/colab_projects/PyTorch-StudioGAN
# Out:
# /content/drive/.shortcut-targets-by-id/1xLQBaAinu05dFe4ZHLlCa9XhQYiiqh1q/colab_projects/PyTorch-StudioGAN

# %% [markdown]
# # Check that everything is ready

# %% [markdown]
# ## Check the data

# %%
# %ls ./data/
# Out:
# cifar10/                                cifar10_test_inception_moments.npz
# cifar10_test_1.0_inception_moments.npz  TINY_ILSVRC2012/

# %%
# %ls ./data/cifar10/
# Out:
# cifar10_32_train.hdf5  cifar-10-batches-py/  cifar-10-python.tar.gz

# %%
# %ls ./data/TINY_ILSVRC2012
# Out:
# __MACOSX/  tiny_imagenet_64_train.hdf5  valid/     words.txt
# test/      train/                       wnids.txt

# %% [markdown]
# ## Check the configs

# %% [markdown]
# Look what files are in the `./src/configs/`

# %%
# %ls ./src/configs/
# Out:
# CIFAR10/  ILSVRC2012/  TINY_ILSVRC2012/

# %%
# %ls ./src/configs/CIFAR10/
# Out:
# ACGAN-Mod.json           BigGAN-Mod.json         ContraGAN.json  SNGAN.json
# BigGAN-Deep-Mod.json     BigGAN-Mod-LO.json      DCGAN.json      WGAN-DRA.json
# BigGAN-Mod-ADA.json      ContraGAN-ADA.json      GGAN.json       WGAN-GP.json
# BigGAN-Mod-CR.json       ContraGAN-CR.json       LSGAN.json      WGAN-WC.json
# BigGAN-Mod-DiffAug.json  ContraGAN-DiffAug.json  ProjGAN.json
# BigGAN-Mod-ICR.json      ContraGAN-ICR.json      SAGAN.json

# %%
# %ls ./src/configs/TINY_ILSVRC2012/
# Out:
# ACGAN-Mod.json           BigGAN-Mod.json         ContraGAN.json  SNGAN.json
# BigGAN-Deep-Mod.json     BigGAN-Mod-LO.json      DCGAN.json      WGAN-DRA.json
# BigGAN-Mod-ADA.json      ContraGAN-ADA.json      GGAN.json       WGAN-GP.json
# BigGAN-Mod-CR.json       ContraGAN-CR.json       LSGAN.json      WGAN-WC.json
# BigGAN-Mod-DiffAug.json  ContraGAN-DiffAug.json  ProjGAN.json
# BigGAN-Mod-ICR.json      ContraGAN-ICR.json      SAGAN.json

# %%
# ImageNet
# %ls ./src/configs/ILSVRC2012/
# Out:
# BigGAN2048.json  BigGAN256_TTUR.json  ContraGAN256.json       SAGAN.json
# BigGAN256.json   ContraGAN2048.json   ContraGAN256_TTUR.json  SNGAN.json

# %% [markdown]
# ## Check the checkpoints
#
# Make empty directories with the same names in `./checkpoints`.
# We'll put the weights there.

# %%
# %mkdir ./checkpoints/CIFAR10
# %mkdir ./checkpoints/ILSVRC2012
# %mkdir ./checkpoints/TINY_ILSVRC2012/

# %%
# %ls ./checkpoints/
# Out:
# CIFAR10/  ILSVRC2012/  TINY_ILSVRC2012/

# %% [markdown]
# Add **Google Drive shortcats** to checkpoints (no need to copy and paste). The links are provided in the following tables:
# * [cifar-10 table](https://github.com/POSTECH-CVLab/PyTorch-StudioGAN#cifar10-3x32x32)
# * [Tiny ImageNet table](https://github.com/POSTECH-CVLab/PyTorch-StudioGAN#tiny-imagenet-3x64x64)
# * [ImageNet table](https://github.com/POSTECH-CVLab/PyTorch-StudioGAN#imagenet-3x128x128)
#
# For now, only add the shortcuts for **ContraGAN** weights for
# * `CIFAR10/`: https://drive.google.com/drive/folders/10nxLyB7PyUsaGiBn6xD0e3_teYlB9Q59?usp=sharing
#
# * `TiNY_ILSVRC2012/`: https://drive.google.com/drive/folders/1wFwCf0Zgjc5ODMNhS_9EPlstNh71ouC_?usp=sharing

# %%
# %ls ./checkpoints/CIFAR10/
# Out:
# ContraGAN-train-2020_10_04_21_50_14@

# %%
# %ls ./checkpoints/TINY_ILSVRC2012/
# Out:
# ContraGAN-train-2021_01_01_09_35_08@

# %% [markdown]
# ## Try generating CIFAR-10 images.

# %%
# %ls src/configs/
# Out:
# CIFAR10/  ILSVRC2012/  TINY_ILSVRC2012/

# %%
# check the config files we have access to
# %ls ./src/configs/CIFAR10/
# Out:
# ACGAN-Mod.json           BigGAN-Mod.json         ContraGAN.json  SNGAN.json
# BigGAN-Deep-Mod.json     BigGAN-Mod-LO.json      DCGAN.json      WGAN-DRA.json
# BigGAN-Mod-ADA.json      ContraGAN-ADA.json      GGAN.json       WGAN-GP.json
# BigGAN-Mod-CR.json       ContraGAN-CR.json       LSGAN.json      WGAN-WC.json
# BigGAN-Mod-DiffAug.json  ContraGAN-DiffAug.json  ProjGAN.json
# BigGAN-Mod-ICR.json      ContraGAN-ICR.json      SAGAN.json

# %%
# this is the needed config
# %ls ./src/configs/CIFAR10/ContraGAN.json
# Out:
# ./src/configs/CIFAR10/ContraGAN.json

# %%
# check the checkpoint folders we have access to
# %ls ./checkpoints/CIFAR10/
# Out:
# ContraGAN-train-2020_10_04_21_50_14@

# %%
# this is the needed folder
# %ls ./checkpoints/CIFAR10/ContraGAN-train-2020_10_04_21_50_14/
# Out:
# 'model=D-best-weights-step=100000.pth'
# 'model=D-current-weights-step=100000.pth'
# 'model=G-best-weights-step=100000.pth'
# 'model=G-current-weights-step=100000.pth'
# 'model=G_ema-best-weights-step=100000.pth'
# 'model=G_ema-current-weights-step=100000.pth'

# %%
# command from https://github.com/POSTECH-CVLab/PyTorch-StudioGAN

# need to change
#   CONFIG_PATH, CHECKPOINT_FOLDER to real path and folder
# !CUDA_VISIBLE_DEVICES=0 python3 src/main.py -e -l -stat_otf -c "./src/configs/CIFAR10/ContraGAN.json" --checkpoint_folder "./checkpoints/CIFAR10/ContraGAN-train-2020_10_04_21_50_14/" --eval_type "test"
# Out:
# cifar10_32_train.hdf5 exist!
# The file are located in the ./data/cifar10/cifar10_32_train.hdf5
# src/main.py:106: UserWarning: You have chosen a specific GPU. This will completely disable data parallelism.
#   warnings.warn('You have chosen a specific GPU. This will completely disable data parallelism.')
# 2021-05-08 10:11:26.272170: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# [INFO] 2021-05-08 10:11:27 > Run name : ContraGAN-train-2021_05_08_10_11_26
# [INFO] 2021-05-08 10:11:27 > {
#   "config_path": "./src/configs/CIFAR10/ContraGAN.json",
#   "checkpoint_folder": "./checkpoints/CIFAR10/ContraGAN-train-2020_10_04_21_50_14/",
#   "load_current": false,
#   "log_output_path": null,
#   "distributed_data_parallel": false,
#   "nodes": 1,
#   "nr": 0,
#   "seed": 314,
#   "num_workers": 8,
#   "synchronized_bn": false,
#   "mixed_precision": false,
#   "LARS_optimizer": false,
#   "disable_debugging_API": false,
#   "reduce_train_dataset": 1.0,
#   "truncated_factor": -1.0,
#   "bn_stat_OnTheFly": true,
#   "standing_statistics": false,
#   "standing_step": -1,
#   "freeze_layers": -1,
#   "load_all_data_in_memory": true,
#   "train": false,
#   "eval": true,
#   "save_images": false,
#   "image_visualization": false,
#   "k_nearest_neighbor": false,
#   "interpolation": false,
#   "frequency_analysis": false,
#   "tsne_analysis": false,
#   "nrow": 10,
#   "ncol": 8,
#   "print_every": 100,
#   "save_every": 2000,
#   "eval_type": "test"
# }
# [INFO] 2021-05-08 10:11:27 > {
#   "data_processing": {
#     "dataset_name": "cifar10",
#     "data_path": "./data/cifar10",
#     "img_size": 32,
#     "num_classes": 10,
#     "batch_size4prcsing": 256,
#     "chunk_size": 500,
#     "compression": false
#   },
#   "train": {
#     "model": {
#       "architecture": "big_resnet",
#       "conditional_strategy": "ContraGAN",
#       "pos_collected_numerator": true,
#       "hypersphere_dim": 512,
#       "bottleneck_dim": "N/A",
#       "nonlinear_embed": false,
#       "normalize_embed": true,
#       "g_spectral_norm": true,
#       "d_spectral_norm": true,
#       "activation_fn": "ReLU",
#       "attention": true,
#       "attention_after_nth_gen_block": 2,
#       "attention_after_nth_dis_block": 1,
#       "z_dim": 80,
#       "shared_dim": 128,
#       "g_conv_dim": 96,
#       "d_conv_dim": 96,
#       "G_depth": "N/A",
#       "D_depth": "N/A",
#       "prior": "gaussian",
#       "ema": true,
#       "ema_decay": 0.9999,
#       "ema_start": 1000
#     },
#     "optimization": {
#       "optimizer": "Adam",
#       "batch_size": 64,
#       "accumulation_steps": 1,
#       "d_lr": 0.0002,
#       "g_lr": 0.0002,
#       "d_weight_decay": 0.0,
#       "g_weight_decay": 0.0,
#       "momentum": "N/A",
#       "nesterov": "N/A",
#       "alpha": "N/A",
#       "beta1": 0.5,
#       "beta2": 0.999,
#       "g_steps_per_iter": 1,
#       "d_steps_per_iter": 5,
#       "total_step": 100000
#     },
#     "loss_function": {
#       "adv_loss": "hinge",
#       "contrastive_lambda": 1.0,
#       "margin": 0.0,
#       "tempering_type": "discrete",
#       "tempering_step": 1,
#       "start_temperature": 1.0,
#       "end_temperature": 1.0,
#       "weight_clipping_for_dis": false,
#       "weight_clipping_bound": "N/A",
#       "gradient_penalty_for_dis": false,
#       "gradient_penalty_lambda": "N/A",
#       "deep_regret_analysis_for_dis": false,
#       "regret_penalty_lambda": "N/A",
#       "cr": false,
#       "cr_lambda": "N/A",
#       "bcr": false,
#       "real_lambda": "N/A",
#       "fake_lambda": "N/A",
#       "zcr": false,
#       "gen_lambda": "N/A",
#       "dis_lambda": "N/A",
#       "sigma_noise": "N/A",
#       "latent_op": false,
#       "latent_op_rate": "N/A",
#       "latent_op_step": "N/A",
#       "latent_op_step4eval": "N/A",
#       "latent_op_alpha": "N/A",
#       "latent_op_beta": "N/A",
#       "latent_norm_reg_weight": "N/A"
#     },
#     "initialization": {
#       "g_init": "ortho",
#       "d_init": "ortho"
#     },
#     "augmentation": {
#       "random_flip_preprocessing": true,
#       "diff_aug": false,
#       "ada": false,
#       "ada_target": "N/A",
#       "ada_length": "N/A"
#     }
#   }
# }
# [INFO] 2021-05-08 10:11:27 > Load train datasets...
# Loading ./data/cifar10/cifar10_32_train.hdf5 into memory...
# [INFO] 2021-05-08 10:11:30 > Train dataset size : 50000
# [INFO] 2021-05-08 10:11:30 > Load test datasets...
# Files already downloaded and verified
# [INFO] 2021-05-08 10:11:36 > Eval dataset size : 10000
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [INFO] 2021-05-08 10:11:36 > Build model...
# [INFO] 2021-05-08 10:11:36 > Modules are located on models.big_resnet.
# [INFO] 2021-05-08 10:11:48 > Prepare EMA for G with decay of 0.9999.
# Initializing EMA parameters to be source parameters...
# [INFO] 2021-05-08 10:11:48 > Number of parameters: 9416196
# [INFO] 2021-05-08 10:11:48 > Generator(
#   (linear0): Linear(in_features=20, out_features=6144, bias=True)
#   (shared): Embedding(10, 128)
#   (blocks): ModuleList(
#     (0): ModuleList(
#       (0): GenBlock(
#         (bn1): ConditionalBatchNorm2d_for_skip_and_shared(
#           (bn): BatchNorm2d(384, eps=0.0001, momentum=0.1, affine=False, track_running_stats=True)
#           (gain): Linear(in_features=148, out_features=384, bias=False)
#           (bias): Linear(in_features=148, out_features=384, bias=False)
#         )
#         (bn2): ConditionalBatchNorm2d_for_skip_and_shared(
#           (bn): BatchNorm2d(384, eps=0.0001, momentum=0.1, affine=False, track_running_stats=True)
#           (gain): Linear(in_features=148, out_features=384, bias=False)
#           (bias): Linear(in_features=148, out_features=384, bias=False)
#         )
#         (activation): ReLU(inplace=True)
#         (conv2d0): Conv2d(384, 384, kernel_size=(1, 1), stride=(1, 1))
#         (conv2d1): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2d2): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (1): ModuleList(
#       (0): GenBlock(
#         (bn1): ConditionalBatchNorm2d_for_skip_and_shared(
#           (bn): BatchNorm2d(384, eps=0.0001, momentum=0.1, affine=False, track_running_stats=True)
#           (gain): Linear(in_features=148, out_features=384, bias=False)
#           (bias): Linear(in_features=148, out_features=384, bias=False)
#         )
#         (bn2): ConditionalBatchNorm2d_for_skip_and_shared(
#           (bn): BatchNorm2d(384, eps=0.0001, momentum=0.1, affine=False, track_running_stats=True)
#           (gain): Linear(in_features=148, out_features=384, bias=False)
#           (bias): Linear(in_features=148, out_features=384, bias=False)
#         )
#         (activation): ReLU(inplace=True)
#         (conv2d0): Conv2d(384, 384, kernel_size=(1, 1), stride=(1, 1))
#         (conv2d1): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2d2): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (2): ModuleList(
#       (0): Self_Attn(
#         (conv1x1_theta): Conv2d(384, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv1x1_phi): Conv2d(384, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv1x1_g): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv1x1_attn): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (softmax): Softmax(dim=-1)
#       )
#     )
#     (3): ModuleList(
#       (0): GenBlock(
#         (bn1): ConditionalBatchNorm2d_for_skip_and_shared(
#           (bn): BatchNorm2d(384, eps=0.0001, momentum=0.1, affine=False, track_running_stats=True)
#           (gain): Linear(in_features=148, out_features=384, bias=False)
#           (bias): Linear(in_features=148, out_features=384, bias=False)
#         )
#         (bn2): ConditionalBatchNorm2d_for_skip_and_shared(
#           (bn): BatchNorm2d(384, eps=0.0001, momentum=0.1, affine=False, track_running_stats=True)
#           (gain): Linear(in_features=148, out_features=384, bias=False)
#           (bias): Linear(in_features=148, out_features=384, bias=False)
#         )
#         (activation): ReLU(inplace=True)
#         (conv2d0): Conv2d(384, 384, kernel_size=(1, 1), stride=(1, 1))
#         (conv2d1): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2d2): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (bn4): BatchNorm2d(384, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#   (activation): ReLU(inplace=True)
#   (conv2d5): Conv2d(384, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (tanh): Tanh()
# )
# [INFO] 2021-05-08 10:11:48 > Number of parameters: 2517186
# [INFO] 2021-05-08 10:11:48 > Discriminator(
#   (blocks): ModuleList(
#     (0): ModuleList(
#       (0): DiscOptBlock(
#         (conv2d0): Conv2d(3, 192, kernel_size=(1, 1), stride=(1, 1))
#         (conv2d1): Conv2d(3, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2d2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (activation): ReLU(inplace=True)
#         (average_pooling): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#     )
#     (1): ModuleList(
#       (0): Self_Attn(
#         (conv1x1_theta): Conv2d(192, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv1x1_phi): Conv2d(192, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv1x1_g): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv1x1_attn): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (softmax): Softmax(dim=-1)
#       )
#     )
#     (2): ModuleList(
#       (0): DiscBlock(
#         (activation): ReLU(inplace=True)
#         (conv2d0): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#         (conv2d1): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2d2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (average_pooling): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#     )
#     (3): ModuleList(
#       (0): DiscBlock(
#         (activation): ReLU(inplace=True)
#         (conv2d1): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2d2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (average_pooling): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#     )
#     (4): ModuleList(
#       (0): DiscBlock(
#         (activation): ReLU(inplace=True)
#         (conv2d1): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2d2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (average_pooling): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#     )
#   )
#   (activation): ReLU(inplace=True)
#   (linear1): Linear(in_features=192, out_features=1, bias=True)
#   (linear2): Linear(in_features=192, out_features=512, bias=True)
#   (embedding): Embedding(10, 512)
# )
# [INFO] 2021-05-08 10:11:53 > Generator checkpoint is ./checkpoints/CIFAR10/ContraGAN-train-2020_10_04_21_50_14/model=G-best-weights-step=100000.pth
# [INFO] 2021-05-08 10:11:53 > Discriminator checkpoint is ./checkpoints/CIFAR10/ContraGAN-train-2020_10_04_21_50_14/model=D-best-weights-step=100000.pth
# /usr/local/lib/python3.7/dist-packages/torchvision/models/inception.py:82: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   ' due to scipy/scipy#11299), please set init_weights=True.', FutureWarning)
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
# 100% 91.2M/91.2M [00:00<00:00, 109MB/s]
# [INFO] 2021-05-08 10:15:08 > Start Evaluation (100000 Step): ContraGAN-train-2020_10_04_21_50_14
# [INFO] 2021-05-08 10:15:08 > Calculating FID Score....
# 100% 157/157 [00:47<00:00,  3.34it/s]
# [INFO] 2021-05-08 10:16:05 > Calculating Inception Score....
# 100% 157/157 [00:46<00:00,  3.41it/s]
# [INFO] 2021-05-08 10:16:52 > Calculate F_beta Score....
# 100% 157/157 [01:27<00:00,  1.79it/s]
# [INFO] 2021-05-08 10:18:36 > Save image to ./figures/ContraGAN-train-2020_10_04_21_50_14/pr_curve.png
# [INFO] 2021-05-08 10:18:37 > Save image to ./figures/ContraGAN-train-2020_10_04_21_50_14/sim_heatmap.png
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [INFO] 2021-05-08 10:18:37 > Calculate Accuracies....
# 100% 156/156 [00:14<00:00, 10.88it/s]
# [INFO] 2021-05-08 10:18:52 > Calculate Accuracies....
# 100% 156/156 [00:02<00:00, 57.72it/s]
# [INFO] 2021-05-08 10:18:55 > F_8 score (Step: 100000, Using test images): 0.9902830343046833
# [INFO] 2021-05-08 10:18:55 > F_1/8 score (Step: 100000, Using test images): 0.9934693315036509
# [INFO] 2021-05-08 10:18:55 > FID score (Step: 100000, Using test moments): 8.126475640545664
# [INFO] 2021-05-08 10:18:55 > Inception score (Step: 100000, 10000 generated images): 9.740926742553711
# [INFO] 2021-05-08 10:18:55 > Best FID score (Step: 100000, Using test moments): 8.064690405539181
# [INFO] 2021-05-08 10:18:55 > Start visualize images....
# [INFO] 2021-05-08 10:18:56 > Saved image to ./figures/ContraGAN-train-2020_10_04_21_50_14/generated_canvas.png

# %% [markdown]
# ## Try generating Tiny Imagenet images.

# %%
# check the config files we have access to
# %ls ./src/configs/TINY_ILSVRC2012/
# Out:
# ACGAN-Mod.json           BigGAN-Mod.json         ContraGAN.json  SNGAN.json
# BigGAN-Deep-Mod.json     BigGAN-Mod-LO.json      DCGAN.json      WGAN-DRA.json
# BigGAN-Mod-ADA.json      ContraGAN-ADA.json      GGAN.json       WGAN-GP.json
# BigGAN-Mod-CR.json       ContraGAN-CR.json       LSGAN.json      WGAN-WC.json
# BigGAN-Mod-DiffAug.json  ContraGAN-DiffAug.json  ProjGAN.json
# BigGAN-Mod-ICR.json      ContraGAN-ICR.json      SAGAN.json

# %%
# check the config files we have access to
# %ls ./src/configs/TINY_ILSVRC2012/ContraGAN.json
# Out:
# ./src/configs/TINY_ILSVRC2012/ContraGAN.json

# %%
# %ls ./checkpoints/TINY_ILSVRC2012/
# Out:
# ContraGAN-train-2021_01_01_09_35_08@

# %%
# %ls ./checkpoints/TINY_ILSVRC2012/ContraGAN-train-2021_01_01_09_35_08/
# Out:
# 'model=D-best-weights-step=54000.pth'
# 'model=D-current-weights-step=100000.pth'
# 'model=G-best-weights-step=54000.pth'
# 'model=G-current-weights-step=100000.pth'
# 'model=G_ema-best-weights-step=54000.pth'
# 'model=G_ema-current-weights-step=100000.pth'

# %%
# command from https://github.com/POSTECH-CVLab/PyTorch-StudioGAN

# need to change
#   CONFIG_PATH, CHECKPOINT_FOLDER to real path and folder
# !CUDA_VISIBLE_DEVICES=0 python3 src/main.py -e -l -stat_otf -c "./src/configs/TINY_ILSVRC2012/ContraGAN.json" --checkpoint_folder "./checkpoints/TINY_ILSVRC2012/ContraGAN-train-2021_01_01_09_35_08/" --eval_type "valid"
# Out:
# tiny_imagenet_64_train.hdf5 exist!
# The file are located in the ./data/TINY_ILSVRC2012/tiny_imagenet_64_train.hdf5
# src/main.py:106: UserWarning: You have chosen a specific GPU. This will completely disable data parallelism.
#   warnings.warn('You have chosen a specific GPU. This will completely disable data parallelism.')
# 2021-05-08 10:44:28.733926: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# [INFO] 2021-05-08 10:44:29 > Run name : ContraGAN-train-2021_05_08_10_44_28
# [INFO] 2021-05-08 10:44:29 > {
#   "config_path": "./src/configs/TINY_ILSVRC2012/ContraGAN.json",
#   "checkpoint_folder": "./checkpoints/TINY_ILSVRC2012/ContraGAN-train-2021_01_01_09_35_08/",
#   "load_current": false,
#   "log_output_path": null,
#   "distributed_data_parallel": false,
#   "nodes": 1,
#   "nr": 0,
#   "seed": 3881,
#   "num_workers": 8,
#   "synchronized_bn": false,
#   "mixed_precision": false,
#   "LARS_optimizer": false,
#   "disable_debugging_API": false,
#   "reduce_train_dataset": 1.0,
#   "truncated_factor": -1.0,
#   "bn_stat_OnTheFly": true,
#   "standing_statistics": false,
#   "standing_step": -1,
#   "freeze_layers": -1,
#   "load_all_data_in_memory": true,
#   "train": false,
#   "eval": true,
#   "save_images": false,
#   "image_visualization": false,
#   "k_nearest_neighbor": false,
#   "interpolation": false,
#   "frequency_analysis": false,
#   "tsne_analysis": false,
#   "nrow": 10,
#   "ncol": 8,
#   "print_every": 100,
#   "save_every": 2000,
#   "eval_type": "valid"
# }
# [INFO] 2021-05-08 10:44:29 > {
#   "data_processing": {
#     "dataset_name": "tiny_imagenet",
#     "data_path": "./data/TINY_ILSVRC2012",
#     "img_size": 64,
#     "num_classes": 200,
#     "batch_size4prcsing": 256,
#     "chunk_size": 500,
#     "compression": false
#   },
#   "train": {
#     "model": {
#       "architecture": "big_resnet",
#       "conditional_strategy": "ContraGAN",
#       "pos_collected_numerator": true,
#       "hypersphere_dim": 768,
#       "bottleneck_dim": "N/A",
#       "nonlinear_embed": false,
#       "normalize_embed": true,
#       "g_spectral_norm": true,
#       "d_spectral_norm": true,
#       "activation_fn": "ReLU",
#       "attention": true,
#       "attention_after_nth_gen_block": 3,
#       "attention_after_nth_dis_block": 1,
#       "z_dim": 100,
#       "shared_dim": 128,
#       "g_conv_dim": 80,
#       "d_conv_dim": 80,
#       "G_depth": "N/A",
#       "D_depth": "N/A",
#       "prior": "gaussian",
#       "ema": true,
#       "ema_decay": 0.9999,
#       "ema_start": 20000
#     },
#     "optimization": {
#       "optimizer": "Adam",
#       "batch_size": 1024,
#       "accumulation_steps": 1,
#       "d_lr": 0.0004,
#       "g_lr": 0.0001,
#       "d_weight_decay": 0.0,
#       "g_weight_decay": 0.0,
#       "momentum": "N/A",
#       "nesterov": "N/A",
#       "alpha": "N/A",
#       "beta1": 0.0,
#       "beta2": 0.999,
#       "g_steps_per_iter": 1,
#       "d_steps_per_iter": 1,
#       "total_step": 100000
#     },
#     "loss_function": {
#       "adv_loss": "hinge",
#       "contrastive_lambda": 1.0,
#       "margin": 0.0,
#       "tempering_type": "discrete",
#       "tempering_step": 1,
#       "start_temperature": 1.0,
#       "end_temperature": 1.0,
#       "weight_clipping_for_dis": false,
#       "weight_clipping_bound": "N/A",
#       "gradient_penalty_for_dis": false,
#       "gradient_penalty_lambda": "N/A",
#       "deep_regret_analysis_for_dis": false,
#       "regret_penalty_lambda": "N/A",
#       "cr": false,
#       "cr_lambda": "N/A",
#       "bcr": false,
#       "real_lambda": "N/A",
#       "fake_lambda": "N/A",
#       "zcr": false,
#       "gen_lambda": "N/A",
#       "dis_lambda": "N/A",
#       "sigma_noise": "N/A",
#       "latent_op": false,
#       "latent_op_rate": "N/A",
#       "latent_op_step": "N/A",
#       "latent_op_step4eval": "N/A",
#       "latent_op_alpha": "N/A",
#       "latent_op_beta": "N/A",
#       "latent_norm_reg_weight": "N/A"
#     },
#     "initialization": {
#       "g_init": "ortho",
#       "d_init": "ortho"
#     },
#     "augmentation": {
#       "random_flip_preprocessing": true,
#       "diff_aug": false,
#       "ada": false,
#       "ada_target": "N/A",
#       "ada_length": "N/A"
#     }
#   }
# }
# [INFO] 2021-05-08 10:44:29 > Load train datasets...
# Loading ./data/TINY_ILSVRC2012/tiny_imagenet_64_train.hdf5 into memory...
# [INFO] 2021-05-08 10:44:35 > Train dataset size : 35323
# [INFO] 2021-05-08 10:44:35 > Load valid datasets...
# [INFO] 2021-05-08 10:44:56 > Eval dataset size : 10000
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [INFO] 2021-05-08 10:44:56 > Build model...
# [INFO] 2021-05-08 10:44:56 > Modules are located on models.big_resnet.
# [INFO] 2021-05-08 10:45:11 > Prepare EMA for G with decay of 0.9999.
# Initializing EMA parameters to be source parameters...
# [INFO] 2021-05-08 10:45:11 > Number of parameters: 17335204
# [INFO] 2021-05-08 10:45:11 > Generator(
#   (linear0): Linear(in_features=20, out_features=20480, bias=True)
#   (shared): Embedding(200, 128)
#   (blocks): ModuleList(
#     (0): ModuleList(
#       (0): GenBlock(
#         (bn1): ConditionalBatchNorm2d_for_skip_and_shared(
#           (bn): BatchNorm2d(1280, eps=0.0001, momentum=0.1, affine=False, track_running_stats=True)
#           (gain): Linear(in_features=148, out_features=1280, bias=False)
#           (bias): Linear(in_features=148, out_features=1280, bias=False)
#         )
#         (bn2): ConditionalBatchNorm2d_for_skip_and_shared(
#           (bn): BatchNorm2d(640, eps=0.0001, momentum=0.1, affine=False, track_running_stats=True)
#           (gain): Linear(in_features=148, out_features=640, bias=False)
#           (bias): Linear(in_features=148, out_features=640, bias=False)
#         )
#         (activation): ReLU(inplace=True)
#         (conv2d0): Conv2d(1280, 640, kernel_size=(1, 1), stride=(1, 1))
#         (conv2d1): Conv2d(1280, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2d2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (1): ModuleList(
#       (0): GenBlock(
#         (bn1): ConditionalBatchNorm2d_for_skip_and_shared(
#           (bn): BatchNorm2d(640, eps=0.0001, momentum=0.1, affine=False, track_running_stats=True)
#           (gain): Linear(in_features=148, out_features=640, bias=False)
#           (bias): Linear(in_features=148, out_features=640, bias=False)
#         )
#         (bn2): ConditionalBatchNorm2d_for_skip_and_shared(
#           (bn): BatchNorm2d(320, eps=0.0001, momentum=0.1, affine=False, track_running_stats=True)
#           (gain): Linear(in_features=148, out_features=320, bias=False)
#           (bias): Linear(in_features=148, out_features=320, bias=False)
#         )
#         (activation): ReLU(inplace=True)
#         (conv2d0): Conv2d(640, 320, kernel_size=(1, 1), stride=(1, 1))
#         (conv2d1): Conv2d(640, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2d2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (2): ModuleList(
#       (0): GenBlock(
#         (bn1): ConditionalBatchNorm2d_for_skip_and_shared(
#           (bn): BatchNorm2d(320, eps=0.0001, momentum=0.1, affine=False, track_running_stats=True)
#           (gain): Linear(in_features=148, out_features=320, bias=False)
#           (bias): Linear(in_features=148, out_features=320, bias=False)
#         )
#         (bn2): ConditionalBatchNorm2d_for_skip_and_shared(
#           (bn): BatchNorm2d(160, eps=0.0001, momentum=0.1, affine=False, track_running_stats=True)
#           (gain): Linear(in_features=148, out_features=160, bias=False)
#           (bias): Linear(in_features=148, out_features=160, bias=False)
#         )
#         (activation): ReLU(inplace=True)
#         (conv2d0): Conv2d(320, 160, kernel_size=(1, 1), stride=(1, 1))
#         (conv2d1): Conv2d(320, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2d2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (3): ModuleList(
#       (0): Self_Attn(
#         (conv1x1_theta): Conv2d(160, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv1x1_phi): Conv2d(160, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv1x1_g): Conv2d(160, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv1x1_attn): Conv2d(80, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (softmax): Softmax(dim=-1)
#       )
#     )
#     (4): ModuleList(
#       (0): GenBlock(
#         (bn1): ConditionalBatchNorm2d_for_skip_and_shared(
#           (bn): BatchNorm2d(160, eps=0.0001, momentum=0.1, affine=False, track_running_stats=True)
#           (gain): Linear(in_features=148, out_features=160, bias=False)
#           (bias): Linear(in_features=148, out_features=160, bias=False)
#         )
#         (bn2): ConditionalBatchNorm2d_for_skip_and_shared(
#           (bn): BatchNorm2d(80, eps=0.0001, momentum=0.1, affine=False, track_running_stats=True)
#           (gain): Linear(in_features=148, out_features=80, bias=False)
#           (bias): Linear(in_features=148, out_features=80, bias=False)
#         )
#         (activation): ReLU(inplace=True)
#         (conv2d0): Conv2d(160, 80, kernel_size=(1, 1), stride=(1, 1))
#         (conv2d1): Conv2d(160, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2d2): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (bn4): BatchNorm2d(80, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#   (activation): ReLU(inplace=True)
#   (conv2d5): Conv2d(80, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (tanh): Tanh()
# )
# [INFO] 2021-05-08 10:45:11 > Number of parameters: 31678130
# [INFO] 2021-05-08 10:45:11 > Discriminator(
#   (blocks): ModuleList(
#     (0): ModuleList(
#       (0): DiscOptBlock(
#         (conv2d0): Conv2d(3, 80, kernel_size=(1, 1), stride=(1, 1))
#         (conv2d1): Conv2d(3, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2d2): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (activation): ReLU(inplace=True)
#         (average_pooling): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#     )
#     (1): ModuleList(
#       (0): Self_Attn(
#         (conv1x1_theta): Conv2d(80, 10, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv1x1_phi): Conv2d(80, 10, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv1x1_g): Conv2d(80, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv1x1_attn): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (softmax): Softmax(dim=-1)
#       )
#     )
#     (2): ModuleList(
#       (0): DiscBlock(
#         (activation): ReLU(inplace=True)
#         (conv2d0): Conv2d(80, 160, kernel_size=(1, 1), stride=(1, 1))
#         (conv2d1): Conv2d(80, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2d2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (average_pooling): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#     )
#     (3): ModuleList(
#       (0): DiscBlock(
#         (activation): ReLU(inplace=True)
#         (conv2d0): Conv2d(160, 320, kernel_size=(1, 1), stride=(1, 1))
#         (conv2d1): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2d2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (average_pooling): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#     )
#     (4): ModuleList(
#       (0): DiscBlock(
#         (activation): ReLU(inplace=True)
#         (conv2d0): Conv2d(320, 640, kernel_size=(1, 1), stride=(1, 1))
#         (conv2d1): Conv2d(320, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2d2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (average_pooling): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#     )
#     (5): ModuleList(
#       (0): DiscBlock(
#         (activation): ReLU(inplace=True)
#         (conv2d0): Conv2d(640, 1280, kernel_size=(1, 1), stride=(1, 1))
#         (conv2d1): Conv2d(640, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2d2): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (average_pooling): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#     )
#   )
#   (activation): ReLU(inplace=True)
#   (linear1): Linear(in_features=1280, out_features=1, bias=True)
#   (linear2): Linear(in_features=1280, out_features=768, bias=True)
#   (embedding): Embedding(200, 768)
# )
# [INFO] 2021-05-08 10:45:17 > Generator checkpoint is ./checkpoints/TINY_ILSVRC2012/ContraGAN-train-2021_01_01_09_35_08/model=G-best-weights-step=54000.pth
# [INFO] 2021-05-08 10:45:18 > Discriminator checkpoint is ./checkpoints/TINY_ILSVRC2012/ContraGAN-train-2021_01_01_09_35_08/model=D-best-weights-step=54000.pth
# /usr/local/lib/python3.7/dist-packages/torchvision/models/inception.py:82: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   ' due to scipy/scipy#11299), please set init_weights=True.', FutureWarning)
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
# 100% 91.2M/91.2M [00:00<00:00, 105MB/s]
# [INFO] 2021-05-08 10:48:26 > Calculate moments of valid dataset
#   0% 0/10 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "src/main.py", line 120, in <module>
#     main()
#   File "src/main.py", line 117, in main
#     prepare_train_eval(rank, gpus_per_node, world_size, run_name, train_configs, model_configs, hdf5_path_train=hdf5_path_train)
#   File "/content/drive/.shortcut-targets-by-id/1xLQBaAinu05dFe4ZHLlCa9XhQYiiqh1q/colab_projects/PyTorch-StudioGAN/src/loader.py", line 212, in prepare_train_eval
#     device=local_rank)
#   File "/content/drive/.shortcut-targets-by-id/1xLQBaAinu05dFe4ZHLlCa9XhQYiiqh1q/colab_projects/PyTorch-StudioGAN/src/metrics/prepare_inception_moments.py", line 41, in prepare_inception_moments
#     run_name=run_name)
#   File "/content/drive/.shortcut-targets-by-id/1xLQBaAinu05dFe4ZHLlCa9XhQYiiqh1q/colab_projects/PyTorch-StudioGAN/src/metrics/FID.py", line 172, in calculate_activation_statistics
#     is_generate, latent_op, latent_op_step, latent_op_alpha, latent_op_beta, device, tqdm_disable, run_name)
#   File "/content/drive/.shortcut-targets-by-id/1xLQBaAinu05dFe4ZHLlCa9XhQYiiqh1q/colab_projects/PyTorch-StudioGAN/src/metrics/FID.py", line 156, in get_activations
#     embeddings, logits = inception_model(images)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/content/drive/.shortcut-targets-by-id/1xLQBaAinu05dFe4ZHLlCa9XhQYiiqh1q/colab_projects/PyTorch-StudioGAN/src/metrics/inception_network.py", line 122, in forward
#     x = block(x)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py", line 119, in forward
#     input = module(input)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/torchvision/models/inception.py", line 477, in forward
#     x = self.bn(x)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/batchnorm.py", line 140, in forward
#     self.weight, self.bias, bn_training, exponential_average_factor, self.eps)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py", line 2150, in batch_norm
#     input, weight, bias, running_mean, running_var, training, momentum, eps, torch.backends.cudnn.enabled
# RuntimeError: CUDA out of memory. Tried to allocate 5.28 GiB (GPU 0; 14.76 GiB total capacity; 9.69 GiB already allocated; 3.90 GiB free; 9.83 GiB reserved in total by PyTorch)
#   0% 0/10 [03:06<?, ?it/s]

# %%
print("All done")
# Out:
# All done
